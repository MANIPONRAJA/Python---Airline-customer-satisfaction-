# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('passenger.csv')

# %%
pd.set_option('display.max_columns', 24)
pd.set_option('display.max_rows', 103904)

# %%
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                  4                       3              1
# ...

# %%
# to calculate number of passengers based on age
plt.style.use('fivethirtyeight') 

ages = df['Age']
 
bins=[10,20,30,40,50,60,70,80,90]

plt.hist(ages, bins=bins, edgecolor='black', log=True) 

median_age = df['Age'].median()
color = '#fc4f30'

plt.axvline(median_age, color=color, label="Age Median")
plt.legend()

plt.title('Ages of Passengers')
plt.xlabel('Ages')
plt.ylabel('Total Passengers')

plt.tight_layout()

plt.show()

print('People who travel most are from age 40-50 due to comfort or maybe mostly business people')
# Out:
# People who travel most are from age 40-50 due to comfort or maybe mostly business people

# %%
plt.style.use('seaborn')

Distance = df['Flight Distance']
Delay = df['Arrival Delay in Minutes']
Cleanliness = df['Cleanliness']

# 
plt.scatter(Distance, Delay, c=Cleanliness, cmap='summer',edgecolor='black',linewidth=1,alpha=0.75)

cbar=plt.colorbar()
cbar.set_label('Cleanliness')

plt.title('Passenger Satisfaction')
plt.xlabel('Distance(km)')
plt.ylabel('Delay(minutes)')

plt.tight_layout()

plt.show()

print('The fights which are travelling more distance are making less delays compare to others but in the shorter travel flight cleanliness are poor due to their repeated travel')
# Out:
# C:\Users\manip\AppData\Local\Temp\ipykernel_4816\2956243515.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# The fights which are travelling more distance are making less delays compare to others but in the shorter travel flight cleanliness are poor due to their repeated travel

# %%
plt.style.use("fivethirtyeight")

class_counts = df['Class'].value_counts()

plt.pie(class_counts, labels = class_counts.index, wedgeprops={'edgecolor': 'black'})

plt.title('Distribution of Travel Classes')
plt.tight_layout()
plt.show()
